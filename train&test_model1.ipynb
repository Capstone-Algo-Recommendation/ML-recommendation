# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.utils import shuffle
from scipy import sparse
import matplotlib.pyplot as plt
# %matplotlib inline
import sys

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sys.path.append('/content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/')
sys.path.append('/content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF')
import Loader
import Metric

# %% [markdown]
# # 1. 학습
# ## 1-1. 데이터 로드

# %%
DIR = '/content/drive/MyDrive/(22-1)캡스톤/recomm/data/preprocessed/'
loader1 = Loader.Loader(DIR, 1, 4)
loader1.load_dataset()
# Out:
# (24032, 2661)

# %%
train = loader1.formatting(0)
train_usr, train_prb, train_entry = shuffle(train[0], train[1], train[2])
train_usr = np.array(train_usr).reshape(-1,1)
train_prb = np.array(train_prb).reshape(-1,1)
train_entry = np.array(train_entry).reshape(-1,1)

# %%
valid_tr, valid_te  = loader1.formatting(1)
valid_te_y, valid_te_X = valid_te
valid_tr_usr, valid_tr_prb, valid_tr_entry = shuffle(valid_tr[0], valid_tr[1], valid_tr[2])
valid_tr_usr = np.array(valid_tr_usr).reshape(-1,1)
valid_tr_prb = np.array(valid_tr_prb).reshape(-1,1)
valid_tr_entry = np.array(valid_tr_entry).reshape(-1,1)

# %%
test_tr, test_te  = loader1.formatting(2)
test_te_y, test_te_X = test_te
test_tr_usr, test_tr_prb, test_tr_entry = shuffle(test_tr[0], test_tr[1], test_tr[2])
test_tr_usr = np.array(test_tr_usr).reshape(-1,1)
test_tr_prb = np.array(test_tr_prb).reshape(-1,1)
test_tr_entry = np.array(test_tr_entry).reshape(-1,1)

# %% [markdown]
# ##1-2. 모델 학습

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

class MF:
    def __init__(self, user_no, prob_no, useridx2level, probidx2level, K=4):
        # 변수
        self.user_no = user_no+5
        self.prob_no = prob_no
        self.useridx2level = useridx2level
        self.probidx2level = probidx2level
        self.K = K
        self.origin_userno = user_no
        self.free_now = 1

        # 레이어
        input_user = tf.keras.layers.Input(shape=(1,), dtype='int32') # 사용자 index 
        input_prob =  tf.keras.layers.Input(shape=(1,), dtype='int32') # 문제 index 
        embedding_user = tf.keras.layers.Flatten()(tf.keras.layers.Embedding(user_no, K)(input_user)) # [사용자 index, 잠재요인]
        embedding_prob =  tf.keras.layers.Flatten()(tf.keras.layers.Embedding(prob_no, K)(input_prob)) # [문제 index, 잠재요인]
        matmul =  tf.keras.layers.Multiply()([embedding_user, embedding_prob]) # new [사용자 index, 문제 index]
        output =  tf.keras.layers.Dense(1)(matmul)

        # 모델
        self.model = tf.keras.Model(inputs=[input_user, input_prob], outputs=output)

    def train(self, model, train_usr, train_prb, train_entry, valid_tr_usr, valid_tr_prb, valid_tr_entry, valid_te_X, valid_te_y, cluster, epochs=100, batch_size=1024, k=30):
      train_N = len(train_usr)
      valid_tr_N = len(valid_tr_usr)
      valid_te_N = len(valid_te_X) 
      rc_vad = [] 
      hr_vad = []
      best_eval = -1
      best_epoch = -1
      BESTMODEL_DIR = '/content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster' + str(cluster)

      for epoch in range(0, epochs):
        ct, tr_loss, vad_loss = 0, 0, 0
        for i in range(0, train_N, batch_size):
          idxlist = range(i, min(i+batch_size, train_N-1))
          hist = self.model.fit([train_usr[idxlist], train_prb[idxlist]], train_entry[idxlist], verbose=0)
          ct+=1
          tr_loss += hist.history['loss'][-1]
        
        print("epoch[", epoch, "] train loss: ", tr_loss / ct)
        weights = self.model.get_weights()

        ct = 0
        for i in range(0, valid_tr_N, batch_size):
          idxlist = range(i, min(i+batch_size, valid_tr_N-1))
          hist = self.model.fit([valid_tr_usr[idxlist], valid_tr_prb[idxlist]], valid_tr_entry[idxlist],verbose=0)
          ct +=1
          vad_loss += hist.history['loss'][-1]
        
        print("epoch[", epoch, "] validation loss: ", vad_loss / ct)
        
        hit_rate = 0
        recall = []
        for i in range(0, valid_te_N):
          usr = valid_te_X.iloc[i,0]
          prbs = np.array(valid_te_X.iloc[i,1])
          usrs = np.array([usr]*len(prbs))
          valid_te_usr = usrs.reshape(-1,1)
          valid_te_prb = prbs.reshape(-1,1)

          pred = self.model.predict([valid_te_usr, valid_te_prb])
          pred = np.concatenate(pred).reshape(-1,1)
          filtered = self.level_filtering(valid_te_usr, valid_te_prb, pred, self.useridx2level, self.probidx2level, k)

          # valid_y
          heldout = np.array(valid_te_y.iloc[i,1])
          recall.append(Metric.recall_at_k(filtered[1], heldout, k))
          hit_rate += Metric.hit_rate_at_k(filtered[1], heldout, k)
          
        recall_ = np.mean(recall)
        rc_vad.append(recall_)
        print("epoch[", epoch, "] recall: ", recall_)

        hit_rate_ = hit_rate/valid_te_N
        hr_vad.append(hit_rate_)
        print("epoch[", epoch, "] hit rate: ", hit_rate_)
        
        self.model.set_weights(weights)
        
        if hit_rate_ > 0.30:
          break

        if hit_rate_ > best_eval:
          best_eval = hit_rate_
          best_epoch = epoch
          self.model.save(BESTMODEL_DIR)

      return rc_vad, hr_vad, best_eval, best_epoch
      

    def test(self, test_tr_usr, test_tr_prb, test_tr_entry, test_te_X, test_te_y, cluster, epochs=20, batch_size=1024, k=30):
      BESTMODEL_DIR = '/content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster' + str(cluster)
      best_model = self.load_model(BESTMODEL_DIR)
      test_tr_N = len(test_tr_usr)
      test_te_N = len(test_te_X)
      test_hit_rate = 0
      test_recall = []
      
      for i in range(0, test_tr_N, batch_size):
          idxlist = range(i, min(i+batch_size, test_tr_N-1))
          self.model.fit([test_tr_usr[idxlist], test_tr_prb[idxlist]], test_tr_entry[idxlist], verbose=0)

      for i in range(0, test_te_N):
        usr = test_te_X.iloc[i,0]
        prbs = np.array(test_te_X.iloc[i,1])
        usrs = np.array([usr]*len(prbs))
        test_te_usr = usrs.reshape(-1,1)
        test_te_prb = prbs.reshape(-1,1)

        pred = self.model.predict([test_te_usr, test_te_prb])
        pred = np.concatenate(pred).reshape(-1,1)
        filtered = self.level_filtering(test_te_usr, test_te_prb, pred, loader1.useridx2level, loader1.probidx2level, k)

        heldout = np.array(test_te_y.iloc[i,1])
        test_recall.append(Metric.recall_at_k(filtered[1], heldout, k))
        test_hit_rate += Metric.hit_rate_at_k(filtered[1], heldout, k)

      recall = np.mean(test_recall)
      test_hit_rate = test_hit_rate/test_te_N

      return recall, test_hit_rate

    def get_model(self):
      return self.model

    def load_model(self, DIR):
      return tf.keras.models.load_model(DIR)

    def level_filtering(self, usr, prb, pred, userlevel_map, problevel_map, k):
      limit = min(k*10, len(pred)-1)
      usr = np.squeeze(usr)
      prb = np.squeeze(prb)
      pred = np.squeeze(pred)
      idx = np.argpartition(-pred, limit)[:limit]

      cdUser = usr[idx]
      cdProb = prb[idx]
      cdPred = pred[idx]

      problevel = np.array([problevel_map[p] for p in cdProb])
      maxlevel = np.array([userlevel_map[u] for u in cdUser]).astype('int64')
      lam = np.mean(cdPred)/100

      dist = np.abs(np.subtract(problevel,maxlevel))*lam
      cdPred = np.subtract(cdPred, dist)
              
      top_idx = np.argsort(-cdPred)[:k]
      top_k_data = (cdUser[top_idx], cdProb[top_idx], cdPred[top_idx])
      
      return top_k_data

# %%
def print_evaluation(vad, eval_type):
  plt.figure(figsize=(12, 3))
  plt.plot(vad)
  plt.ylabel("Validation " + eval_type + "@30")
  plt.xlabel("Epochs")

# %%
mf = MF(loader1.users_no, loader1.prob_no, loader1.useridx2level, loader1.probidx2level)
model = mf.get_model()

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-2)
model.compile(optimizer=optimizer, loss='mse')

# %%
rc_vad, hr_vad, best_eval, best_epoch = mf.train(model, train_usr, train_prb, train_entry, valid_tr_usr, valid_tr_prb, valid_tr_entry, valid_te_X, valid_te_y, 1, epochs=100, batch_size=1024, k=30)
# Out:
# epoch[ 0 ] train loss:  0.16017523035407066
# epoch[ 0 ] validation loss:  0.1600773412599621
# epoch[ 0 ] recall:  0.0052145024933471125
# epoch[ 0 ] hit rate:  0.061706783369803064
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 1 ] train loss:  0.16016617911131698
# epoch[ 1 ] validation loss:  0.16007711307471056
# epoch[ 1 ] recall:  0.005358850823699944
# epoch[ 1 ] hit rate:  0.06389496717724288
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 2 ] train loss:  0.1601651667188922
# epoch[ 2 ] validation loss:  0.1600803135030241
# epoch[ 2 ] recall:  0.005354230224408216
# epoch[ 2 ] hit rate:  0.06433260393873086
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 3 ] train loss:  0.16016432299805775
# epoch[ 3 ] validation loss:  0.16007701226745744
# epoch[ 3 ] recall:  0.0053217840469660695
# epoch[ 3 ] hit rate:  0.06389496717724288
# epoch[ 4 ] train loss:  0.16016391617430858
# epoch[ 4 ] validation loss:  0.16007293540849743
# epoch[ 4 ] recall:  0.005352234163012787
# epoch[ 4 ] hit rate:  0.06520787746170678
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 5 ] train loss:  0.16016189130218345
# epoch[ 5 ] validation loss:  0.160074598189578
# epoch[ 5 ] recall:  0.005182258064481229
# epoch[ 5 ] hit rate:  0.06345733041575492
# epoch[ 6 ] train loss:  0.1601616216802788
# epoch[ 6 ] validation loss:  0.16007469854800097
# epoch[ 6 ] recall:  0.00550030289253518
# epoch[ 6 ] hit rate:  0.06608315098468272
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 7 ] train loss:  0.16016003250634772
# epoch[ 7 ] validation loss:  0.16007144210568394
# epoch[ 7 ] recall:  0.005716577265981513
# epoch[ 7 ] hit rate:  0.06739606126914661
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 8 ] train loss:  0.1601580516211275
# epoch[ 8 ] validation loss:  0.16006846824683338
# epoch[ 8 ] recall:  0.0060344433392732575
# epoch[ 8 ] hit rate:  0.07045951859956236
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 9 ] train loss:  0.16015494957970486
# epoch[ 9 ] validation loss:  0.160065778856536
# epoch[ 9 ] recall:  0.00656543460070364
# epoch[ 9 ] hit rate:  0.07221006564551423
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 10 ] train loss:  0.16015081921116933
# epoch[ 10 ] validation loss:  0.16006305113614325
# epoch[ 10 ] recall:  0.006718285027438462
# epoch[ 10 ] hit rate:  0.07264770240700219
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 11 ] train loss:  0.1601445844027176
# epoch[ 11 ] validation loss:  0.16005541411149932
# epoch[ 11 ] recall:  0.007690611907069023
# epoch[ 11 ] hit rate:  0.0774617067833698
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 12 ] train loss:  0.1601361060691894
# epoch[ 12 ] validation loss:  0.16004313313099275
# epoch[ 12 ] recall:  0.008819942316862603
# epoch[ 12 ] hit rate:  0.08183807439824946
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 13 ] train loss:  0.16012167405571362
# epoch[ 13 ] validation loss:  0.16002435062125506
# epoch[ 13 ] recall:  0.010429896906960983
# epoch[ 13 ] hit rate:  0.08927789934354485
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 14 ] train loss:  0.16009800192588797
# epoch[ 14 ] validation loss:  0.15999534465821394
# epoch[ 14 ] recall:  0.012896926887644617
# epoch[ 14 ] hit rate:  0.10021881838074398
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 15 ] train loss:  0.1600542654881642
# epoch[ 15 ] validation loss:  0.15992954611239663
# epoch[ 15 ] recall:  0.017667230335068698
# epoch[ 15 ] hit rate:  0.11772428884026258
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 16 ] train loss:  0.15996091752674813
# epoch[ 16 ] validation loss:  0.15978117197392935
# epoch[ 16 ] recall:  0.029543577775127117
# epoch[ 16 ] hit rate:  0.15579868708971553
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 17 ] train loss:  0.15971972664264655
# epoch[ 17 ] validation loss:  0.1593149342989347
# epoch[ 17 ] recall:  0.0642507928000729
# epoch[ 17 ] hit rate:  0.23719912472647703
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# epoch[ 18 ] train loss:  0.15880812398639177
# epoch[ 18 ] validation loss:  0.15691748216568704
# epoch[ 18 ] recall:  0.1307233901752648
# epoch[ 18 ] hit rate:  0.37242888402625823
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/(22-1)캡스톤/recomm/Recommendation/model/MF/best_model/cluster1/assets
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-1b60b089e8eb> in <module>()
# ----> 1 rc_vad, hr_vad, best_eval, best_epoch = mf.train(model, train_usr, train_prb, train_entry, valid_tr_usr, valid_tr_prb, valid_tr_entry, valid_te_X, valid_te_y, 1, epochs=100, batch_size=1024, k=30)
#
# <ipython-input-44-c6e1191e6818> in train(self, model, train_usr, train_prb, train_entry, valid_tr_usr, valid_tr_prb, valid_tr_entry, valid_te_X, valid_te_y, cluster, epochs, batch_size, k)
#      39         for i in range(0, train_N, batch_size):
#      40           idxlist = range(i, min(i+batch_size, train_N-1))
# ---> 41           hist = self.model.fit([train_usr[idxlist], train_prb[idxlist]], train_entry[idxlist], verbose=0)
#      42           ct+=1
#      43           tr_loss += hist.history['loss'][-1]
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1370           self._maybe_load_initial_epoch_from_ckpt(initial_epoch))
#    1371       logs = None
# -> 1372       for epoch, iterator in data_handler.enumerate_epochs():
#    1373         self.reset_metrics()
#    1374         callbacks.on_epoch_begin(epoch)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1189     """Yields `(epoch, tf.data.Iterator)`."""
#    1190     with self._truncate_execution_to_epoch():
# -> 1191       data_iterator = iter(self._dataset)
#    1192       for epoch in range(self._initial_epoch, self._epochs):
#    1193         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3314     try:
#    3315       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3316         _ctx, "MakeIterator", name, dataset, iterator)
#    3317       return _result
#    3318     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print_evaluation(rc_vad[:-1], "Recall")

# %%
print_evaluation(hr_vad[:-1], "Hit Rate")

# %% [markdown]
# # 1-3. test

# %%
recall, test_hit_rate = mf.test(test_tr_usr, test_tr_prb, test_tr_entry, test_te_X, test_te_y, cluster=1, epochs=20, batch_size=1024, k=30)
print("recall: ", recall)
print("hit rate: ", test_hit_rate)
# Out:
# recall:  0.006091045042487366
# hit rate:  0.06914660831509847
