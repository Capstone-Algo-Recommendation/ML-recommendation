# %%
import os
import pandas as pd
import numpy as np

# %%
class Loader:
  def __init__(self):
    self.DIR = '/content/drive/MyDrive/(22-1)캡스톤/recomm/data/'
  
  def load_dataset(self, data_no):
    self.DATASET_DIR = self.DIR + 'preprocessed/data' + data_no

    # 데이터 로드
    train = pd.read_csv(os.path.join(self.DIR, 'd'+data_no+'_train.csv'))
    valid_X = pd.read_csv(os.path.join(self.DIR, 'd'+data_no+'_validation_X.csv'))
    valid_y = pd.read_csv(os.path.join(self.DIR, 'd'+data_no+'_validation_y.csv'))
    test_X = pd.read_csv(os.path.join(self.DIR, 'd'+data_no+'_test_X.csv'))
    test_y = pd.read_csv(os.path.join(self.DIR, 'd'+data_no+'_test_y.csv'))

    # ID 테이블


    # 문제 난이도 테이블
